# %%
# To ignore unimporant system warnings
import warnings
warnings.filterwarnings("ignore")

# Import libaries
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

import usaddress
import os

# %%
url = "https://www1.nyc.gov/site/mome/industries/studios-stages.page"
req = requests.get(url)
soup = BeautifulSoup(req.text, "lxml")

# %%
#get addresses from each table row
facilities = []

content = soup.find_all('tr')
for i, row in enumerate(content):
    #skip header
    if i == 0:
        continue
        
        
    cell = row.find_all('td')[0]
    facility = row.find_all('td')[-1].text
    try:
        title = cell.find('strong').text
    except:
        title = cell.find('a').text   

    text = cell.get_text(separator = ',', strip = True)
    address = text.replace(title,'', 1)
    address = address.replace(',','', 1)
    facilities.append([title,address,facility])

# %%
facilities_df = pd.DataFrame(facilities, columns = ['Name','Address','Type'])
facilities_df.head()
# Out:
#                        Name  \
# 0             1717 Troutman
# 1  The 1896 Studio & Stages
# 2         19th Avenue Stage
# 3               718 Studios
# 4              94 Jewel St.
#
#                                              Address            Type
# 0     1717 Troutman Street, #300,Ridgewood, NY 11385  Not applicable
# 1  592 Johnson Avenue/,211-215 Ingraham Avenue,Br...         Level 1
# 2            19-02 Steinway Street,Astoria, NY 11105         Level 2
# 3  130 Thames Street,Brooklyn, NY 11247,718studio...  Not applicable
# 4  94 Jewel Street, Ground level,Brooklyn, NY 112...  Not applicable

# %%
facilities_df2 = pd.read_csv('facilities_df_geocoded.csv')

# %%
#clean up addresses before geocoding
def cleanAddreses(row):
    addr = row['Address']
    #past to usaddrees, if it fails use blank
    try:
        addr_tags = usaddress.tag(row['Address'])[0]
    except:
        return ''
    
    #use keep array to order a return with the address items needed + comma before zipcode
    keep_addr_tags = ['AddressNumber','StreetNamePreDirectional', 'StreetName', 'StreetNamePostType', '_Comma', 'ZipCode']
    addr_tags['_Comma'] = ','
    cleaned_addr = ''
    
    for tag in keep_addr_tags:
        if tag in addr_tags:
            cleaned_addr = f'{cleaned_addr} {addr_tags[tag]}'
    return cleaned_addr
        
facilities_df2['_Address'] = facilities_df2.apply(cleanAddreses, axis = 1)

facilities_df2['_Address']
# Out:
# 0        1717 Troutman Street , 11385
# 1          592 Johnson Avenue , 11237
# 2       19-02 Steinway Street , 11105
# 3           130 Thames Street , 11247
# 4             94 Jewel Street , 11222
#                     ...
# 124         21-10 51st Avenue , 11101
# 125           3905 2nd Avenue , 11232
# 126      320 West 66th Street , 10023
# 127      300 Kingsland Avenue , 11234
# 128               55 Broadway , 10007
# Name: _Address, Length: 129, dtype: object

# %%
facilities_df2.head()
# Out:
#                        Name                                           Address  \
# 0             1717 Troutman    1717 Troutman Street, #300,Ridgewood, NY 11385
# 1  The 1896 Studio & Stages             592 Johnson Avenue,Brooklyn, NY 11237
# 2         19th Avenue Stage           19-02 Steinway Street,Astoria, NY 11105
# 3               718 Studios              130 Thames Street,Brooklyn, NY 11247
# 4              94 Jewel St.  94 Jewel Street, Ground level,Brooklyn, NY 11222
#
#              Type                        _Address  lat  lng  bbl
# 0  Not applicable    1717 Troutman Street , 11385  NaN  NaN  NaN
# 1         Level 1      592 Johnson Avenue , 11237  NaN  NaN  NaN
# 2         Level 2   19-02 Steinway Street , 11105  NaN  NaN  NaN
# 3  Not applicable       130 Thames Street , 11247  NaN  NaN  NaN
# 4  Not applicable         94 Jewel Street , 11222  NaN  NaN  NaN

# %%
#if file exist then import, otherwise copy from facilities_df... this will help with manual fixes
file = 'facilities_df_geocoded.csv'
if os.path.exists(file):
    facilities_df_geocoded = pd.read_csv(file)
else:
    facilities_df_geocoded = facilities_df2.copy()
    facilities_df_geocoded.to_csv(file, index = False)
    print('facilities_df_geocoded generated')
# facilities_df_geocoded = facilities_df2.copy()

geocoded = []
def geocode(row):
    lat, lng = np.nan, np.nan
    if 'bbl' in row:
        bbl = row['bbl']
    else:
        bbl = np.nan
    addr = row['_Address']
    #only geocode if bbl is blank (NA) and addr is not empty
    if pd.isna(bbl) and (addr != '' and pd.notna(addr)):
        print(bbl, addr)
        
        #geocode! 
        url = f'https://geosearch.planninglabs.nyc/v1/search?text={addr}&size=120'
        r = requests.get(url)
        features = r.json()['features']
        if len(features):
            feature = features[0]
            lng, lat = feature['geometry']['coordinates']
            bbl = feature['properties']['pad_bbl']

    
    return pd.Series([lat,lng, bbl])
    

facilities_df_geocoded[['lat','lng','bbl']] = facilities_df_geocoded.apply(geocode, axis = 1)
    
#save results to file
facilities_df_geocoded.to_csv('facilities_df_geocoded.csv', index = False)
# Out:
# nan  1717 Troutman Street , 11385
# nan  592 Johnson Avenue , 11237
# nan  19-02 Steinway Street , 11105
# nan  130 Thames Street , 11247
# nan  94 Jewel Street , 11222
# nan  630 Flushing Avenue , 11206
# nan  221 West 26th Street , 10001
# nan  123 Bowery , 10002
# nan  81 Walker Street , 10013
# nan  570 Lexington Avenue , 10022
# nan  524 Broadway , 10012
# nan  11-05 44th Road , 11101
# nan  268 Mulberry Street , 10012
# nan  52 Bridge Street , 11201
# nan  42-24 Ninth Street , 11101
# nan 152 West 25th Street, 10001
# nan  1298-1304 Willoughby Ave , 11237
# nan  352 Troutman Street , 11237
# nan  102-120 Ingraham Street , 11237
# nan  1028 Grand Street , 11237
# nan  272 Seigel Street , 11206
# nan  229 West 28th Street , 10001
# nan  445 Albee Square , 11201
# nan  457 Broome Street , 10013
# nan  18 West 21st Street , 10010
# nan  34-31 10th Street , 11106
# nan  235 Bond Street , 11217
# nan 40 West 27th Street, 10001
# nan  20 Brick Ct , 10309
# nan  203 Meserole Ave , 11222
# nan  259 Greene Street , 11222
# nan  47-60 29th Street ,
# nan  8-16 43rd Avenue , 11101
# nan  524 West 57th Street , 10019
# nan  305 Ten Eyck Street , 11206
# nan  62 Chelsea Piers , 10011
# nan  420 Kent Avenue , 11211
# nan  11 29, 33 Kent Street , 11222
# nan  1245 Grand Street , 11211
# nan 220 Dupont Street, 11222
# nan  435 West 19th Street , 10011
# nan  67 West Street , 11222
# nan  1 N 12th St , 11211
# nan  150 West 28th Street , 10001
# nan  130 West 29th Street , 10001
# nan  173 E. 120th St. , 10035
# nan  245 West 55th Street , 10019
# nan  140 53rd Street , 11232
# nan  1260 Atlantic Avenue , 11216
# nan 270 Nevins Street, 11217
# nan 479 Degraw Street, 11217
# nan 302 Sheffield Avenue, 11207
# nan  21-29 45th Road , 11101
# nan  164 West 25th Street , 10001
# nan  325 West 37th Street , 10018
# nan  247 Water Street , 11201
# nan  34-02 Laurel Hill Boulevard , 11378
# nan  28 W 36th St. , 10018
# nan  470 Flushing Avenue , 11205
# nan  44 West 24th Street , 10010
# nan  356 Devoe Street , 11211
# nan  250 West 54th Street , 10019
# nan  2-15 Borden Avenue , 11101
# nan  4502 2nd Avenue , 11232
# nan  46 West 116th Street , 10026
# nan  2-15 26th Avenue , 11102
# nan  36 East 30th Street , 10016
# nan  440 West 15th Street , 10011
# nan  873 Broadway , 10003
# nan  36-11 20th Avenue , 11105
# nan  775 Washington Street , 10014
# nan  118 West 22nd Street , 10011
# nan  168 53rd Street , 11232
# nan  34-12 36th Street , 11106
# nan  146 East 44th Street , 10017
# nan  3835 205th Street) , 10034
# nan  74 S. 1st Street , 11211
# nan  40 Ludlow Street , 10002
# nan  122 West 27th Street , 10001
# nan  311 West 34th Street , 10001
# nan  253 West 28th Street , 10001
# nan  125 West 18th Street , 10011
# nan  163 Bank Street , 10014
# nan  152 44th Street , 11232
# nan  63 Rivington Street , 10002
# nan  248 East 35th Street , 10016
# nan  30 Rockefeller Plaza , 10112
# nan  232 Madison Avenue , 10016
# nan  31 Howard Street , 10013
# nan  22 West 27th Street , 10001
# nan  183-16 Jamaica Avenue , 11423
# nan  10-15 44th Avenue , 11101
# nan  333 Hudson Street , 10013
# nan  10-26a 46th Avenue , 11101
# nan  59 Chelsea Piers , 10011
# nan  159 Pioneer Street , 11231
# nan  873 Broadway , 10003
# nan  2138 44th Rd , 11101
# nan  146 West 29th Street , 10001
# nan  4865 Arthur Kill Road , 10309
# nan  67 West Street , 11221
# nan  525 Waverly Avenue , 11238
# nan  32 Clinton Street , 10002
# nan  67 West Street , 11222
# nan  100 Sutton_Street , 11222
# nan  13 Laight Street , 10013
# nan  528 West 39th Street , 10018
# nan  630 Flushing Avenue , 11206
# nan  42-22 22nd Street , 11101
# nan  East 34-02 Starr Ave , 11101
# nan  295 Locust Avenue , 10454
# nan  508 West 37th Street , 10018
# nan  610 Smith Street , 11231
# nan 36-01 37th Avenue, 11101
# nan  84 Orchard Street , 10002
# nan  150 Greenwich Street , 10007
# nan  37-18 Northern Boulevard , 11101
# nan  207 Starr Street , 11237
# nan  560 Bay Street , 10304
# nan  15 Washington Avenue , 11205
# nan  301 Ten Eyck Street , 11206
# nan  21-07 Borden Avenue , 11101
# nan  1659 Cody Avenue , 11385
# nan  873 Broadway , 10003
# nan  21-10 51st Avenue , 11101
# nan  3905 2nd Avenue , 11232
# nan  320 West 66th Street , 10023
# nan  300 Kingsland Avenue , 11234
# nan  55 Broadway , 10007
