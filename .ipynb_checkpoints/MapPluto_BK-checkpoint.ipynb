# %%
import warnings
warnings.filterwarnings("ignore")

import requests
import numpy as np
import pandas as pd
import geopandas as gpd # GeoPandas library for spatial analytics

# %%
MapPluto = gpd.read_file("../vector/MapPluto_BK")

# %%
sel_1 = MapPluto[MapPluto['CD']==301]
sel_2 = MapPluto[MapPluto['CD']==302]
sel_3 = MapPluto[MapPluto['CD']==303]
sel_4 = MapPluto[MapPluto['CD']==306]
MapPluto_sel = pd.concat([sel_1, sel_2,sel_3,sel_4])

# %%
MapPluto_sel.head()
# Out:
#       Borough  Block   Lot   CD  BCT2020    BCTCB2020 CT2010 CB2010  \
# 50097      BK   1638    46  301  3054900  30549002024    549   2012
# 53042      BK   2128     5  301  3054900  30549002013    549   2006
# 53044      BK   2129     5  301  3054900  30549001003    549   1003
# 53046      BK   2129  7501  301  3054900  30549001003    549   1003
# 53047      BK   2129  7504  301  3054900  30549001003    549   1003
#
#       SchoolDist  Council  ...  FIRM07_FLA PFIRM15_FL  Version  DCPEdited  \
# 50097         14       34  ...        None       None     22v1       None
# 53042         14       33  ...           1          1     22v1       None
# 53044         14       33  ...        None       None     22v1       None
# 53046         14       33  ...        None       None     22v1       None
# 53047         14       33  ...        None       None     22v1       None
#
#         Latitude  Longitude Notes Shape_Leng    Shape_Area  \
# 50097  40.689003 -73.924230  None        0.0   2122.691135
# 53042  40.710288 -73.969052  None        0.0  47019.600705
# 53044  40.710378 -73.968258  None        0.0   2394.473389
# 53046  40.710145 -73.967465  None        0.0  15389.281174
# 53047  40.710167 -73.967674  None        0.0   4504.745050
#
#                                                 geometry
# 50097  POLYGON ((1005317.014 190305.935, 1005213.392 ...
# 53042  POLYGON ((992940.600 198169.938, 992946.085 19...
# 53044  POLYGON ((993103.500 198092.672, 993100.007 19...
# 53046  POLYGON ((993404.617 198034.684, 993389.444 19...
# 53047  POLYGON ((993230.814 198059.463, 993231.520 19...
#
# [5 rows x 95 columns]
